# %% [markdown]
# <a href="https://colab.research.google.com/github/harsh-tambi/ANN_Multiclassifier_MNIST/blob/main/ANN_Multiclassifier_MNIST.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Installing all the dependencies and importing the required libraries
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Loading the data
mnist = tf.keras.datasets.mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()
#Normalising the data
x_train, x_test = x_train/255.0, x_test/255.0
print ("x_train.shape = ", x_train.shape)
# Out:
# x_train.shape =  (60000, 28, 28)

# %%
from keras.engine import input_layer
#Building the model
model = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(10, activation='softmax')
])

# %%
#Compiling the model
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
#Training the model
r = model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 13s 6ms/step - loss: 0.2997 - accuracy: 0.9125 - val_loss: 0.1431 - val_accuracy: 0.9584
# Epoch 2/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.1455 - accuracy: 0.9564 - val_loss: 0.1037 - val_accuracy: 0.9681
# Epoch 3/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.1080 - accuracy: 0.9675 - val_loss: 0.0903 - val_accuracy: 0.9718
# Epoch 4/10
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0897 - accuracy: 0.9720 - val_loss: 0.0787 - val_accuracy: 0.9759
# Epoch 5/10
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0745 - accuracy: 0.9767 - val_loss: 0.0759 - val_accuracy: 0.9781
# Epoch 6/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0673 - accuracy: 0.9783 - val_loss: 0.0716 - val_accuracy: 0.9776
# Epoch 7/10
# ...

# %%
plt.plot(r.history['loss'], label='loss')
plt.plot(r.history['val_loss'], label='val_loss')
plt.legend()

# %%
plt.plot(r.history['accuracy'], label='accuracy')
plt.plot(r.history['val_accuracy'], label='val_accuracy')
plt.legend()

# %%
print (model.evaluate(x_test, y_test))
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0689 - accuracy: 0.9794
# [0.06889370828866959, 0.9793999791145325]

# %%
print ("Harsh")
# Out:
# Harsh
